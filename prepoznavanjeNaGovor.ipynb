# %%
import sys
# !{sys.executable} -m pip install librosa tensorflowjs
# Out:
# Requirement already satisfied: librosa in c:\users\marti\anaconda3\lib\site-packages (0.8.0)
# Collecting tensorflowjs
#   Using cached tensorflowjs-3.3.0-py3-none-any.whl (63 kB)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (0.23.2)
# Requirement already satisfied: numba>=0.43.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (0.51.2)
# Requirement already satisfied: pooch>=1.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (1.3.0)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.9.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: audioread>=2.0.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: joblib>=0.14 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (0.17.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (1.19.2)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflowjs) (2.4.1)
# Requirement already satisfied: tensorflow-hub<0.10,>=0.7.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflowjs) (0.9.0)
# Requirement already satisfied: six<2,>=1.12.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: h5py<3,>=2.8.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflowjs) (2.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\marti\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\marti\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in c:\users\marti\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (50.3.1.post20201107)
# Requirement already satisfied: requests in c:\users\marti\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.24.0)
# Requirement already satisfied: appdirs in c:\users\marti\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: packaging in c:\users\marti\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (20.4)
# Requirement already satisfied: cffi>=1.0 in c:\users\marti\anaconda3\lib\site-packages (from soundfile>=0.9.0->librosa) (1.14.3)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.4.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.7.4.3)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.4.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.12.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.3.3)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.32.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.15.6)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12.1)
# Requirement already satisfied: wheel~=0.35 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.35.1)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\marti\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\marti\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marti\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\marti\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (1.25.11)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\marti\anaconda3\lib\site-packages (from packaging->pooch>=1.0->librosa) (2.4.7)
# Requirement already satisfied: pycparser in c:\users\marti\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.20)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\marti\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\marti\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\marti\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\marti\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (1.28.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\marti\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\marti\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\marti\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\marti\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\marti\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\marti\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Installing collected packages: tensorflowjs
# Successfully installed tensorflowjs-3.3.0
# Processing c:\users\marti\appdata\local\pip\cache\wheels\aa\5a\92\d52f6f8560ff05a2525e6030a1903412df876714241fb76802\librosa-0.8.0-py3-none-any.whl
# Collecting tensorflowjs
#   Using cached tensorflowjs-3.3.0-py3-none-any.whl (63 kB)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (4.4.2)
# Collecting audioread>=2.0.0
#   Using cached audioread-2.1.9.tar.gz (377 kB)
# Collecting pooch>=1.0
#   Using cached pooch-1.3.0-py3-none-any.whl (51 kB)
# Collecting resampy>=0.2.2
#   Using cached resampy-0.2.2.tar.gz (323 kB)
# Requirement already satisfied: numba>=0.43.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (0.51.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (0.23.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (1.19.2)
# Collecting soundfile>=0.9.0
#   Using cached SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-win_amd64.whl (689 kB)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\marti\anaconda3\lib\site-packages (from librosa) (0.17.0)
# Collecting tensorflow-hub<0.10,>=0.7.0
#   Using cached tensorflow_hub-0.9.0-py2.py3-none-any.whl (103 kB)
# Collecting tensorflow<3,>=2.1.0
#   Using cached tensorflow-2.4.1-cp38-cp38-win_amd64.whl (370.7 MB)
# Requirement already satisfied: h5py<3,>=2.8.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflowjs) (2.10.0)
# Requirement already satisfied: six<2,>=1.12.0 in c:\users\marti\anaconda3\lib\site-packages (from tensorflowjs) (1.15.0)
# Collecting appdirs
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in c:\users\marti\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.24.0)
# Requirement already satisfied: packaging in c:\users\marti\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (20.4)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\marti\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in c:\users\marti\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (50.3.1.post20201107)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\marti\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\marti\anaconda3\lib\site-packages (from soundfile>=0.9.0->librosa) (1.14.3)
# Collecting protobuf>=3.8.0
#   Using cached protobuf-3.15.6-py2.py3-none-any.whl (173 kB)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.12.0-py3-none-any.whl (129 kB)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.7.4.3)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Using cached tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# Collecting gast==0.3.3
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting grpcio~=1.32.0
#   Using cached grpcio-1.32.0-cp38-cp38-win_amd64.whl (2.6 MB)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorboard~=2.4
#   Using cached tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
# Collecting wrapt~=1.12.1
#   Using cached wrapt-1.12.1.tar.gz (27 kB)
# Collecting termcolor~=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: wheel~=0.35 in c:\users\marti\anaconda3\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.35.1)
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marti\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\marti\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\marti\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\marti\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\marti\anaconda3\lib\site-packages (from packaging->pooch>=1.0->librosa) (2.4.7)
# Requirement already satisfied: pycparser in c:\users\marti\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.20)
# Collecting google-auth<2,>=1.6.3
#   Using cached google_auth-1.28.0-py2.py3-none-any.whl (136 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.3-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\marti\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow<3,>=2.1.0->tensorflowjs) (1.0.1)
# Collecting cachetools<5.0,>=2.0.0
#   Using cached cachetools-4.2.1-py3-none-any.whl (12 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Building wheels for collected packages: audioread, resampy, wrapt, termcolor
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23146 sha256=12cf193f22c018dc82b4610786584f34d3dfc421895b275175233858941a3d66
#   Stored in directory: c:\users\marti\appdata\local\pip\cache\wheels\49\5a\e4\df590783499a992a88de6c0898991d1167453a3196d0d1eeb7
#   Building wheel for resampy (setup.py): started
#   Building wheel for resampy (setup.py): finished with status 'done'
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320724 sha256=1c51d6b53e54dcaea44d5259d2635f26bcf576df1e23d862e806d20f193e400c
#   Stored in directory: c:\users\marti\appdata\local\pip\cache\wheels\6f\d1\5d\f13da53b1dcbc2624ff548456c9ffb526c914f53c12c318bb4
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-py3-none-any.whl size=19558 sha256=3aeac3fb1c97a904bc6242f96f3bb3920d1cb84231d91f8fde0cf1bf8c9f2e03
#   Stored in directory: c:\users\marti\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=84682d59d639470b29487af7c4a393a4589ffeecabf5ff11e3697e32d6001926
#   Stored in directory: c:\users\marti\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built audioread resampy wrapt termcolor
# Installing collected packages: audioread, appdirs, pooch, resampy, soundfile, librosa, protobuf, tensorflow-hub, absl-py, flatbuffers, keras-preprocessing, tensorflow-estimator, gast, grpcio, google-pasta, cachetools, pyasn1, pyasn1-modules, rsa, google-auth, tensorboard-plugin-wit, oauthlib, requests-oauthlib, google-auth-oauthlib, markdown, tensorboard, wrapt, termcolor, opt-einsum, astunparse, tensorflow, tensorflowjs
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.11.2
#     Uninstalling wrapt-1.11.2:
#       Successfully uninstalled wrapt-1.11.2
# Successfully installed absl-py-0.12.0 appdirs-1.4.4 astunparse-1.6.3 audioread-2.1.9 cachetools-4.2.1 flatbuffers-1.12 gast-0.3.3 google-auth-1.28.0 google-auth-oauthlib-0.4.3 google-pasta-0.2.0 grpcio-1.32.0 keras-preprocessing-1.1.2 librosa-0.8.0 markdown-3.3.4 oauthlib-3.1.0 opt-einsum-3.3.0 pooch-1.3.0 protobuf-3.15.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 resampy-0.2.2 rsa-4.7.2 soundfile-0.10.3.post1 tensorboard-2.4.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.4.1 tensorflow-estimator-2.4.0 tensorflow-hub-0.9.0 tensorflowjs-3.3.0 termcolor-1.1.0 wrapt-1.12.1

# %%
# !{sys.executable} -m pip install --upgrade pip
# Out:
# Collecting pip
#   Using cached pip-21.0.1-py3-none-any.whl (1.5 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 20.2.4
#     Uninstalling pip-20.2.4:
#       Successfully uninstalled pip-20.2.4
# Successfully installed pip-21.0.1

# %%
import glob
import json
import os
import random

import librosa
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from scipy.io import wavfile
import tensorflow as tf
import tensorflowjs as tfjs
import tqdm

print(tf.__version__)
print(tfjs.__version__)
# Out:
# 2.4.1
# 3.3.0

# %%
# !mkdir tmp\tfjs-sc-model
# !cd tfjs-sc-model
!

# %%
# Out:
# A subdirectory or file tmp\tfjs-sc-model already exists.
